# %%
import math
import string
import sys

# %%
 
       with open(D:/Docs/1.txt, 'r') as f:
       data = f.read()
       return data
# Out:
#   File "<ipython-input-8-769f5ec30f00>", line 2
#     with open(D:/Docs/1.txt, 'r') as f:
#     ^
# IndentationError: unexpected indent
