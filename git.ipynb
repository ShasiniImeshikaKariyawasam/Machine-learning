# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/
# %cd ML
# Out:
# /content/gdrive/My Drive
# /content/gdrive/My Drive/ML

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/My Drive/ML/.git/

# %%
# !git config --global user.email 'sashi.imeshika@gmail.com'

# %%
# !git config --global user.name 'ShasiniImeshikaKariyawasam'

# %%
# !git add .
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git commit -m "Colab Commit"
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git remote add origin https://ShasiniImeshikaKariyawasam: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@github.com/ShasiniImeshikaKariyawasam/Machine-learning.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git push -u origin master --force
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git remote rm origin
