# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/
# %cd ML
# Out:
# /content/gdrive/My Drive
# /content/gdrive/My Drive/ML

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/ML/.git/

# %%
# !git config --global user.email 'sashi.imeshika@gmail.com'

# %%
# !git config --global user.name 'ShasiniImeshikaKariyawasam'

# %%
# !git add .

# %%
# !git commit -m "Colab Commit"
# Out:
# On branch master
# Changes not staged for commit:
# 	modified:   git.ipynb
#
# no changes added to commit

# %%
# !git remote add origin https://ShasiniImeshikaKariyawasam:#Rathnawa@github.com/ShasiniImeshikaKariyawasam/Machine-learning.git

# %%
# !git push -u origin master --force
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://ShasiniImeshikaKariyawasam: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@github.com/ShasiniImeshikaKariyawasam/Machine-learning.git/'

# %%
# !git remote rm origin
