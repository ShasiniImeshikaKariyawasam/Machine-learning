# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/
# %cd ML
# Out:
# /content/gdrive/My Drive
# /content/gdrive/My Drive/ML

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/ML/.git/

# %%
# !git config --global user.email 'sashi.imeshika@gmail.com'

# %%
# !git config --global user.name 'ShasiniImeshikaKariyawasam'

# %%
# !git add .

# %%
# !git commit -m "Colab Commit"
# Out:
# [master c19193e] Colab Commit
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git remote add origin https://ShasiniImeshikaKariyawasam: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@github.com/ShasiniImeshikaKariyawasam/Machine-learning.git

# %%
# !git push -u origin master --force
# Out:
# fatal: unable to access 'https://ShasiniImeshikaKariyawasam:#Rathnawali14@github.com/ShasiniImeshikaKariyawasam/Machine-learning.git/': Could not resolve host: ShasiniImeshikaKariyawasam

# %%
# !git remote rm origin
