# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/
# %cd ML
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-28-ce04cdd9d7ad>", line 1, in <module>
#     get_ipython().magic('cd gdrive/My Drive/')
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-84>", line 2, in cd
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
# ...

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/ML/.git/

# %%
# !git config --global user.email 'sashi.imeshika@gmail.com'

# %%
# !git config --global user.name 'ShasiniImeshikaKariyawasam'

# %%
# !git add .

# %%
# !git commit -m "Colab Commit"
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git remote add origin https://ShasiniImeshikaKariyawasam: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@github.com/ShasiniImeshikaKariyawasam/Machine-learning.git
# Out:
# fatal: remote origin already exists.

# %%
# !git push -u origin master --force
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://ShasiniImeshikaKariyawasam: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@github.com/ShasiniImeshikaKariyawasam/Machine-learning.git/'

# %%
# !git remote rm origin
