# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/
# %cd ML
# Out:
# /content/gdrive/My Drive
# /content/gdrive/My Drive/ML

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/ML/.git/

# %%
# !git config --global user.email 'sashi.imeshika@gmail.com'

# %%
# !git config --global user.name 'ShasiniImeshikaKariyawasam'

# %%
# !git add .

# %%
# !git commit -m "Colab Commit"
# Out:
# [master 5e9cb55] Colab Commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite git.ipynb (94%)

# %%
# !git remote add origin https://ShasiniImeshikaKariyawasam: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@github.com/ShasiniImeshikaKariyawasam/Machine-learning.git

# %%
# !git push -u origin master --force
# Out:
# remote: Permission to ShasiniImeshikaKariyawasam/Machine-learning.git denied to ShasiniImeshikaKariyawasam.
# fatal: unable to access 'https://ShasiniImeshikaKariyawasam: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@github.com/ShasiniImeshikaKariyawasam/Machine-learning.git/': The requested URL returned error: 403

# %%
# !git remote rm origin
